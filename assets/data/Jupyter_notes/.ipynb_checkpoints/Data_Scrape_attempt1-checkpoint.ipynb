# %%
import pandas as pd

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2019_rookies.html"

# %%
tables = pd.read_html(url)

# %%
tables
# Out:
# [    Unnamed: 0_level_0      Unnamed: 1_level_0        Unnamed: 2_level_0  \
#                      Rk                  Player                     Debut
#  0                    1            Jaylen Adams    Oct 17, '18, ATL @ NYK
#  1                    2               Deng Adel    Jan 19, '19, CLE @ DEN
#  2                    3  DeVaughn Akoon-Purcell  Oct 23, '18, DEN vs. SAC
#  3                    4            Rawle Alkins    Dec 17, '18, CHI @ OKC
#  4                    5           Grayson Allen  Oct 22, '18, UTA vs. MEM
#  5                    6    Kostas Antetokounmpo    Mar 20, '19, DAL @ POR
#  6                    7           Deandre Ayton  Oct 17, '18, PHO vs. DAL
#  7                    8           Marvin Bagley  Oct 17, '18, SAC vs. UTA
#  8                    9                Mo Bamba  Oct 17, '18, ORL vs. MIA
#  9                   10        Keita Bates-Diop  Oct 26, '18, MIN vs. MIL
#  10                  11          Dairis Bertāns    Mar 10, '19, NOP @ ATL
# ...

# %%
df = tables[0]
columns = ["Rk", "Player", "Debut", "Age", "Yrs", "G","MP", "FG", "FGA", "3P", "3PA", "FT", "FTA","ORB","TRB", "AST", "STL", "BLK","TOV","PF", "PTS", "FG%","3P%","FT%", "MP", "PS/G", "TRB", "AST"]

# %%
len(columns)
# Out:
# 28

# %%
df.columns = columns
